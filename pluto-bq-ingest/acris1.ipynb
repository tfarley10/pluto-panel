# %%
import pandas as pd
import requests
import os
from google.cloud import storage
from google.cloud import bigquery

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = 'secret.json'

# %%
client = storage.Client()
bucket = client.get_bucket('raw-pluto')
bq_client = bigquery.Client()

# %% [markdown]
# [API Docs](https://dev.socrata.com/foundry/data.cityofnewyork.us/ic3t-wcy2)
# [OpenData](https://data.cityofnewyork.us/Housing-Development/DOB-Job-Application-Filings/ic3t-wcy2)
# [Metadata](https://docs.google.com/spreadsheets/d/1TGe-YvR-rqV3sTm2DVl9icoiypo3ug-GDdP1ULdo1_s/edit#gid=169410431)

# %%
cols=[
'job__',
'doc__',
'bin__',
'borough',
'block',
'lot',
'latest_action_date',
'pre__filing_date',
'job_type',
'job_status',
'initial_cost',
'building_class',
'existing_occupancy',
'proposed_occupancy',
'existing_dwelling_units',
'proposed_dwelling_units',
'existingno_of_stories',
'proposed_no_of_stories',
'job_status_descrp'
]

col_string=','.join(cols)

# %%
LIMIT=10**3
JOB_APPLICATIONS=f'https://data.cityofnewyork.us/resource/bnx9-e6tj.json?$order=recorded_datetime desc&$limit={LIMIT}'

# %%
get_request=f'{JOB_APPLICATIONS}'

d=requests.get(get_request).json()

# %%
d
# d2=pd.DataFrame(d)
# Out:
# [{'document_id': '2021090100350001',
#   'record_type': 'A',
#   'crfn': '2021000431719',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2020-12-28T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-31T00:00:00.000',
#   'modified_date': '2021-10-31T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700485002',
#   'record_type': 'A',
#   'crfn': '2021000430241',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '880137.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700485001',
#   'record_type': 'A',
#   'crfn': '2021000430240',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '900000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600068003',
#   'record_type': 'A',
#   'crfn': '2021000430239',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600068002',
#   'record_type': 'A',
#   'crfn': '2021000430238',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '630000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600068001',
#   'record_type': 'A',
#   'crfn': '2021000430237',
#   'recorded_borough': '1',
#   'doc_type': 'CORRD',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601244001',
#   'record_type': 'A',
#   'crfn': '2021000430236',
#   'recorded_borough': '1',
#   'doc_type': 'DTL',
#   'document_date': '2021-10-20T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601146001',
#   'record_type': 'A',
#   'crfn': '2021000430235',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601110001',
#   'record_type': 'A',
#   'crfn': '2021000430234',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601108001',
#   'record_type': 'A',
#   'crfn': '2021000430233',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601070001',
#   'record_type': 'A',
#   'crfn': '2021000430232',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-07-12T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102400049004',
#   'record_type': 'A',
#   'crfn': '2021000430231',
#   'recorded_borough': '4',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-15T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102400049003',
#   'record_type': 'A',
#   'crfn': '2021000430230',
#   'recorded_borough': '4',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-15T00:00:00.000',
#   'document_amt': '435000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102400049002',
#   'record_type': 'A',
#   'crfn': '2021000430229',
#   'recorded_borough': '4',
#   'doc_type': 'PAT',
#   'document_date': '2021-08-15T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102400049001',
#   'record_type': 'A',
#   'crfn': '2021000430228',
#   'recorded_borough': '4',
#   'doc_type': 'PAT',
#   'document_date': '2021-08-30T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601065001',
#   'record_type': 'A',
#   'crfn': '2021000430227',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '409900.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601010001',
#   'record_type': 'A',
#   'crfn': '2021000430226',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600967001',
#   'record_type': 'A',
#   'crfn': '2021000430225',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '390000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600993001',
#   'record_type': 'A',
#   'crfn': '2021000430224',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600951001',
#   'record_type': 'A',
#   'crfn': '2021000430223',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501325001',
#   'record_type': 'A',
#   'crfn': '2021000430222',
#   'recorded_borough': '4',
#   'doc_type': 'TL&R',
#   'document_date': '2021-10-20T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600426001',
#   'record_type': 'A',
#   'crfn': '2021000430221',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-09-30T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501077001',
#   'record_type': 'A',
#   'crfn': '2021000430220',
#   'recorded_borough': '4',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600825001',
#   'record_type': 'A',
#   'crfn': '2021000430219',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-20T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600767001',
#   'record_type': 'A',
#   'crfn': '2021000430218',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-08-20T00:00:00.000',
#   'document_amt': '386000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600732002',
#   'record_type': 'A',
#   'crfn': '2021000430217',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '477360.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600732001',
#   'record_type': 'A',
#   'crfn': '2021000430216',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '494000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101400266001',
#   'record_type': 'A',
#   'crfn': '2021000430215',
#   'recorded_borough': '3',
#   'doc_type': 'DEED',
#   'document_date': '2021-09-17T00:00:00.000',
#   'document_amt': '240000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500924001',
#   'record_type': 'A',
#   'crfn': '2021000430214',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-08-26T00:00:00.000',
#   'document_amt': '10.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100400883001',
#   'record_type': 'A',
#   'crfn': '2021000430213',
#   'recorded_borough': '3',
#   'doc_type': 'DEED',
#   'document_date': '2021-08-27T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101200575001',
#   'record_type': 'A',
#   'crfn': '2021000430212',
#   'recorded_borough': '3',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-11T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200029001',
#   'record_type': 'A',
#   'crfn': '2021000430211',
#   'recorded_borough': '3',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600737001',
#   'record_type': 'A',
#   'crfn': '2021000430210',
#   'recorded_borough': '1',
#   'doc_type': 'M&CON',
#   'document_date': '2021-10-14T00:00:00.000',
#   'document_amt': '430760.46',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600771001',
#   'record_type': 'A',
#   'crfn': '2021000430209',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600744001',
#   'record_type': 'A',
#   'crfn': '2021000430208',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021092900721001',
#   'record_type': 'A',
#   'crfn': '2021000430207',
#   'recorded_borough': '3',
#   'doc_type': 'SAT',
#   'document_date': '2021-09-28T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600684002',
#   'record_type': 'A',
#   'crfn': '2021000430206',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-12T00:00:00.000',
#   'document_amt': '220000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600684001',
#   'record_type': 'A',
#   'crfn': '2021000430205',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-12T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600711001',
#   'record_type': 'A',
#   'crfn': '2021000430204',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600669001',
#   'record_type': 'A',
#   'crfn': '2021000430203',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329012',
#   'record_type': 'A',
#   'crfn': '2021000430202',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '30200000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329011',
#   'record_type': 'A',
#   'crfn': '2021000430201',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '14075000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329010',
#   'record_type': 'A',
#   'crfn': '2021000430200',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '14075000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329008',
#   'record_type': 'A',
#   'crfn': '2021000430198',
#   'recorded_borough': '1',
#   'doc_type': 'TL&R',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329006',
#   'record_type': 'A',
#   'crfn': '2021000430196',
#   'recorded_borough': '1',
#   'doc_type': 'AL&R',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '14075000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329005',
#   'record_type': 'A',
#   'crfn': '2021000430195',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '14075000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329004',
#   'record_type': 'A',
#   'crfn': '2021000430194',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '7085371.99',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329003',
#   'record_type': 'A',
#   'crfn': '2021000430193',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329002',
#   'record_type': 'A',
#   'crfn': '2021000430192',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '20480000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501329001',
#   'record_type': 'A',
#   'crfn': '2021000430191',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '38.580000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700103002',
#   'record_type': 'A',
#   'crfn': '2021000430185',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-08-16T00:00:00.000',
#   'document_amt': '586000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700103001',
#   'record_type': 'A',
#   'crfn': '2021000430184',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-08-16T00:00:00.000',
#   'document_amt': '731500.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700217001',
#   'record_type': 'A',
#   'crfn': '2021000430183',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-26T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700111001',
#   'record_type': 'A',
#   'crfn': '2021000430182',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-26T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200849002',
#   'record_type': 'A',
#   'crfn': '2021000430181',
#   'recorded_borough': '2',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200849001',
#   'record_type': 'A',
#   'crfn': '2021000430180',
#   'recorded_borough': '2',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600991001',
#   'record_type': 'A',
#   'crfn': '2021000430179',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600980001',
#   'record_type': 'A',
#   'crfn': '2021000430178',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600969001',
#   'record_type': 'A',
#   'crfn': '2021000430177',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600929003',
#   'record_type': 'A',
#   'crfn': '2021000430176',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-10-06T00:00:00.000',
#   'document_amt': '537545.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600929002',
#   'record_type': 'A',
#   'crfn': '2021000430175',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-06T00:00:00.000',
#   'document_amt': '14383.90',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600929001',
#   'record_type': 'A',
#   'crfn': '2021000430174',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-05-03T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600965001',
#   'record_type': 'A',
#   'crfn': '2021000430173',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501054001',
#   'record_type': 'A',
#   'crfn': '2021000430172',
#   'recorded_borough': '4',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600889004',
#   'record_type': 'A',
#   'crfn': '2021000430171',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '570000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600889003',
#   'record_type': 'A',
#   'crfn': '2021000430170',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '950000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600889002',
#   'record_type': 'A',
#   'crfn': '2021000430169',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-05-17T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600889001',
#   'record_type': 'A',
#   'crfn': '2021000430168',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-05-17T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102201289001',
#   'record_type': 'A',
#   'crfn': '2021000430167',
#   'recorded_borough': '1',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '350000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200307001',
#   'record_type': 'A',
#   'crfn': '2021000430166',
#   'recorded_borough': '1',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '175000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600848001',
#   'record_type': 'A',
#   'crfn': '2021000430165',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '371441.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600799001',
#   'record_type': 'A',
#   'crfn': '2021000430164',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-09-17T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102001512001',
#   'record_type': 'A',
#   'crfn': '2021000430163',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2020-09-29T00:00:00.000',
#   'document_amt': '33918.75',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600656001',
#   'record_type': 'A',
#   'crfn': '2021000430162',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-09-01T00:00:00.000',
#   'document_amt': '425000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600672001',
#   'record_type': 'A',
#   'crfn': '2021000430161',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-21T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102001312001',
#   'record_type': 'A',
#   'crfn': '2021000430160',
#   'recorded_borough': '1',
#   'doc_type': 'SMIS',
#   'document_date': '2021-10-07T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102000213001',
#   'record_type': 'A',
#   'crfn': '2021000430159',
#   'recorded_borough': '1',
#   'doc_type': 'SMIS',
#   'document_date': '2021-10-14T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600655001',
#   'record_type': 'A',
#   'crfn': '2021000430158',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600645001',
#   'record_type': 'A',
#   'crfn': '2021000430157',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-18T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500408005',
#   'record_type': 'A',
#   'crfn': '2021000430156',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '1264000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500408004',
#   'record_type': 'A',
#   'crfn': '2021000430155',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500408003',
#   'record_type': 'A',
#   'crfn': '2021000430154',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '1580000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500408002',
#   'record_type': 'A',
#   'crfn': '2021000430153',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-01T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500408001',
#   'record_type': 'A',
#   'crfn': '2021000430152',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-01T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700390001',
#   'record_type': 'A',
#   'crfn': '2021000430147',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-06-10T00:00:00.000',
#   'document_amt': '769146.46',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700278001',
#   'record_type': 'A',
#   'crfn': '2021000430146',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-07-10T00:00:00.000',
#   'document_amt': '1954453.38',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700267001',
#   'record_type': 'A',
#   'crfn': '2021000430145',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700255001',
#   'record_type': 'A',
#   'crfn': '2021000430144',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-26T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700235001',
#   'record_type': 'A',
#   'crfn': '2021000430143',
#   'recorded_borough': '1',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '150000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700175001',
#   'record_type': 'A',
#   'crfn': '2021000430142',
#   'recorded_borough': '1',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-19T00:00:00.000',
#   'document_amt': '230000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501254003',
#   'record_type': 'A',
#   'crfn': '2021000430141',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-18T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501254002',
#   'record_type': 'A',
#   'crfn': '2021000430140',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-18T00:00:00.000',
#   'document_amt': '2249250.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501254001',
#   'record_type': 'A',
#   'crfn': '2021000430139',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-18T00:00:00.000',
#   'document_amt': '2999000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600932001',
#   'record_type': 'A',
#   'crfn': '2021000430138',
#   'recorded_borough': '1',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '510000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301519002',
#   'record_type': 'A',
#   'crfn': '2021000430137',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301519001',
#   'record_type': 'A',
#   'crfn': '2021000430136',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301539002',
#   'record_type': 'A',
#   'crfn': '2021000430135',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301539001',
#   'record_type': 'A',
#   'crfn': '2021000430134',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600924001',
#   'record_type': 'A',
#   'crfn': '2021000430133',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101500383002',
#   'record_type': 'A',
#   'crfn': '2021000430132',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-14T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101500383001',
#   'record_type': 'A',
#   'crfn': '2021000430131',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-14T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301548002',
#   'record_type': 'A',
#   'crfn': '2021000430130',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301548001',
#   'record_type': 'A',
#   'crfn': '2021000430129',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301552002',
#   'record_type': 'A',
#   'crfn': '2021000430128',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101301552001',
#   'record_type': 'A',
#   'crfn': '2021000430127',
#   'recorded_borough': '4',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600910004',
#   'record_type': 'A',
#   'crfn': '2021000430126',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-07-03T00:00:00.000',
#   'document_amt': '406000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600910003',
#   'record_type': 'A',
#   'crfn': '2021000430125',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-07-03T00:00:00.000',
#   'document_amt': '11148.65',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600910002',
#   'record_type': 'A',
#   'crfn': '2021000430124',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-06-15T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102600910001',
#   'record_type': 'A',
#   'crfn': '2021000430123',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-07-03T00:00:00.000',
#   'document_amt': '0.00',
# ...
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700436004',
#   'record_type': 'A',
#   'crfn': '2021000431107',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-10-06T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700436003',
#   'record_type': 'A',
#   'crfn': '2021000431106',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-15T00:00:00.000',
#   'document_amt': '300000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700436002',
#   'record_type': 'A',
#   'crfn': '2021000431105',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-09-09T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700436001',
#   'record_type': 'A',
#   'crfn': '2021000431104',
#   'recorded_borough': '1',
#   'doc_type': 'PAT',
#   'document_date': '2021-09-09T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102001375001',
#   'record_type': 'A',
#   'crfn': '2021000431103',
#   'recorded_borough': '3',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-20T00:00:00.000',
#   'document_amt': '1100000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102500518001',
#   'record_type': 'A',
#   'crfn': '2021000431102',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-22T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101500918001',
#   'record_type': 'A',
#   'crfn': '2021000431101',
#   'recorded_borough': '3',
#   'doc_type': 'RPTT&RET',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '660000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700071001',
#   'record_type': 'A',
#   'crfn': '2021000431100',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-26T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700058001',
#   'record_type': 'A',
#   'crfn': '2021000431099',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700051001',
#   'record_type': 'A',
#   'crfn': '2021000431098',
#   'recorded_borough': '1',
#   'doc_type': 'SUBM',
#   'document_date': '2020-08-28T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700035001',
#   'record_type': 'A',
#   'crfn': '2021000431097',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102700031001',
#   'record_type': 'A',
#   'crfn': '2021000431096',
#   'recorded_borough': '1',
#   'doc_type': 'SAT',
#   'document_date': '2021-10-25T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200352004',
#   'record_type': 'A',
#   'crfn': '2021000431095',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-09-15T00:00:00.000',
#   'document_amt': '270000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200352003',
#   'record_type': 'A',
#   'crfn': '2021000431094',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-09-15T00:00:00.000',
#   'document_amt': '5479.24',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200352002',
#   'record_type': 'A',
#   'crfn': '2021000431093',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-08-17T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102200352001',
#   'record_type': 'A',
#   'crfn': '2021000431092',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-08-19T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601798001',
#   'record_type': 'A',
#   'crfn': '2021000431091',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-10-12T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102601750001',
#   'record_type': 'A',
#   'crfn': '2021000431090',
#   'recorded_borough': '1',
#   'doc_type': 'M&CON',
#   'document_date': '2021-08-26T00:00:00.000',
#   'document_amt': '489765.93',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501215002',
#   'record_type': 'A',
#   'crfn': '2021000431089',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-10-12T00:00:00.000',
#   'document_amt': '760000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102501215001',
#   'record_type': 'A',
#   'crfn': '2021000431088',
#   'recorded_borough': '1',
#   'doc_type': 'DEED',
#   'document_date': '2021-10-12T00:00:00.000',
#   'document_amt': '950000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101800343002',
#   'record_type': 'A',
#   'crfn': '2021000431087',
#   'recorded_borough': '1',
#   'doc_type': 'CERT',
#   'document_date': '2021-07-09T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101800343001',
#   'record_type': 'A',
#   'crfn': '2021000431086',
#   'recorded_borough': '1',
#   'doc_type': 'ZONE',
#   'document_date': '2021-08-24T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101801342003',
#   'record_type': 'A',
#   'crfn': '2021000431085',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-09-30T00:00:00.000',
#   'document_amt': '1100000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101801342002',
#   'record_type': 'A',
#   'crfn': '2021000431084',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-09-30T00:00:00.000',
#   'document_amt': '81805.39',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021101801342001',
#   'record_type': 'A',
#   'crfn': '2021000431083',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-08-24T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100800430005',
#   'record_type': 'A',
#   'crfn': '2021000431082',
#   'recorded_borough': '1',
#   'doc_type': 'SUBM',
#   'document_date': '2021-08-09T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100800430004',
#   'record_type': 'A',
#   'crfn': '2021000431081',
#   'recorded_borough': '1',
#   'doc_type': 'AGMT',
#   'document_date': '2021-09-03T00:00:00.000',
#   'document_amt': '598600.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100800430003',
#   'record_type': 'A',
#   'crfn': '2021000431080',
#   'recorded_borough': '1',
#   'doc_type': 'MTGE',
#   'document_date': '2021-09-03T00:00:00.000',
#   'document_amt': '79441.98',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100800430002',
#   'record_type': 'A',
#   'crfn': '2021000431079',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-08-23T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021100800430001',
#   'record_type': 'A',
#   'crfn': '2021000431078',
#   'recorded_borough': '1',
#   'doc_type': 'ASST',
#   'document_date': '2021-08-23T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '0.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800835001',
#   'record_type': 'A',
#   'crfn': '2021000431077',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-10-05T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800786001',
#   'record_type': 'A',
#   'crfn': '2021000431076',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-10-08T00:00:00.000',
#   'document_amt': '1700000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800506001',
#   'record_type': 'A',
#   'crfn': '2021000431075',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-10-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800450001',
#   'record_type': 'A',
#   'crfn': '2021000431074',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-09-13T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800393001',
#   'record_type': 'A',
#   'crfn': '2021000431073',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-09-20T00:00:00.000',
#   'document_amt': '0.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'},
#  {'document_id': '2021102800324001',
#   'record_type': 'A',
#   'crfn': '2021000431072',
#   'recorded_borough': '2',
#   'doc_type': 'RPTT',
#   'document_date': '2021-09-17T00:00:00.000',
#   'document_amt': '550000.00',
#   'recorded_datetime': '2021-10-29T00:00:00.000',
#   'modified_date': '2021-10-29T00:00:00.000',
#   'reel_yr': '0',
#   'reel_nbr': '0',
#   'reel_pg': '0',
#   'percent_trans': '100.000000',
#   'good_through_date': '2021-10-31T00:00:00.000'}]

# %%
d2
# Out:
#              document_id record_type           crfn recorded_borough  \
# 0       2021101401084001           A  2021000414052                1
# 1       2021100501582001           A  2021000403281                1
# 2       2021092200107004           A  2021000403280                1
# 3       2021092200107003           A  2021000403279                1
# 4       2021092200107002           A  2021000403278                1
# ...                  ...         ...            ...              ...
# 999995  2018122600662002           A  2018000426188                1
# 999996  2018111900384001           A  2018000408264                1
# 999997  2018121801568002           A  2018000420106                1
# 999998  2018120701008003           A  2018000405287                1
# 999999  2018101600339001           A  2018000417325                3
#
#         doc_type            document_date document_amt  \
# 0           AGMT  2021-08-10T00:00:00.000   2034590.37
# 1            PAT  2021-09-05T00:00:00.000         0.00
# 2           AL&R  2021-09-22T00:00:00.000    748877.00
# 3           AGMT  2021-09-22T00:00:00.000    748877.00
# 4           MTGE  2021-09-22T00:00:00.000     17647.72
# ...          ...                      ...          ...
# 999995      MTGE  2018-12-13T00:00:00.000       814000
# 999996      MTGE  2018-11-16T00:00:00.000   1563470.55
# 999997      MTGE  2018-12-07T00:00:00.000       499900
# 999998       PAT  2018-10-11T00:00:00.000            0
# 999999  RPTT&RET  2018-10-03T00:00:00.000       544000
#
#               recorded_datetime            modified_date reel_yr reel_nbr  \
# 0       2021-10-20T00:00:00.000  2021-10-20T00:00:00.000       0        0
# 1       2021-10-14T00:00:00.000  2021-10-14T00:00:00.000       0        0
# 2       2021-10-14T00:00:00.000  2021-10-14T00:00:00.000       0        0
# 3       2021-10-14T00:00:00.000  2021-10-14T00:00:00.000       0        0
# 4       2021-10-14T00:00:00.000  2021-10-14T00:00:00.000       0        0
# ...                         ...                      ...     ...      ...
# 999995  2018-12-27T00:00:00.000  2018-12-27T00:00:00.000       0        0
# 999996  2018-12-11T00:00:00.000  2018-12-11T00:00:00.000       0        0
# 999997  2018-12-21T00:00:00.000  2018-12-21T00:00:00.000       0        0
# 999998  2018-12-10T00:00:00.000  2018-12-10T00:00:00.000       0        0
# 999999  2018-12-19T00:00:00.000  2018-12-19T00:00:00.000       0        0
#
#        reel_pg percent_trans        good_through_date
# 0            0      0.000000  2021-10-31T00:00:00.000
# 1            0      0.000000  2021-10-31T00:00:00.000
# 2            0      0.000000  2021-10-31T00:00:00.000
# 3            0      0.000000  2021-10-31T00:00:00.000
# 4            0      0.000000  2021-10-31T00:00:00.000
# ...        ...           ...                      ...
# 999995       0             0  2018-12-31T00:00:00.000
# 999996       0             0  2018-12-31T00:00:00.000
# 999997       0             0  2018-12-31T00:00:00.000
# 999998       0             0  2018-12-31T00:00:00.000
# 999999       0           100  2018-12-31T00:00:00.000
#
# [1000000 rows x 14 columns]

# %%
table_id='pluto-panel.raw_pluto.raw_job_applications'

job_config = bigquery.LoadJobConfig(
        autodetect=True,
        write_disposition='WRITE_TRUNCATE'

        )

# %%
job = bq_client.load_table_from_dataframe(
    d2, table_id, job_config=job_config
)  # Make an API request.
job.result()  # Wait for the job to complete.

# %%
table = bq_client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 1774179 rows and 19 columns to pluto-panel.raw_pluto.raw_job_applications

# %% [markdown]
# ## DOB NOW permits
# [OpenData](https://data.cityofnewyork.us/Housing-Development/DOB-NOW-Build-Job-Application-Filings/w9ak-ipjd)
# [API Docs](https://dev.socrata.com/foundry/data.cityofnewyork.us/bty7-2jhb)

# %%
d2.yr=d2.latest_action_date.str.split('/', expand = True)[2]

# %%
NOW_APPLICATIONS='https://data.cityofnewyork.us/resource/w9ak-ipjd.json?$'

# %%
resp=requests.get(NOW_APPLICATIONS)
d=resp.json()

# %%
df=pd.DataFrame(d)

# %%
# for c in df.columns:
#     print(c)

# %%
hist_cols=[
    'job_filing_number',
    'filing_status',
    'borough',
    'block',
    'lot',
    'bin',
    'initial_cost',
    'building_type',
    'existing_dwelling_units',
    'proposed_dwelling_units',
    'job_type',
    'existing_stories',
    'proposed_no_of_stories',
    'existing_height',
    'proposed_height',
    'filing_date',
    'current_status_date'
    
]
hist_colstring=','.join(hist_cols)

# %%
get_request=f'{NOW_APPLICATIONS}limit={LIMIT}&$select={hist_colstring}'


now=requests.get(get_request).json()

# %%
df=pd.DataFrame(now)

# %%
table_id='pluto-panel.raw_pluto.raw_job_now_applications'

job_config = bigquery.LoadJobConfig(
        autodetect=True,
        write_disposition='WRITE_TRUNCATE'

        )

# %%
job = bq_client.load_table_from_dataframe(
    df, table_id, job_config=job_config
)  # Make an API request.
job.result()  # Wait for the job to complete.

# %%
table = bq_client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
